# %% [markdown]
# Title: Descriptive Analysis of a Food Outlet Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HyderabadResturants.csv")

# %%
df.head()
# Out:
#                                                links                names  \
# 0  https://www.zomato.com/hyderabad/sahara-bakers...        Sahara Bakers
# 1   https://www.zomato.com/hyderabad/kfc-abids/order                  KFC
# 2  https://www.zomato.com/hyderabad/subbaiah-gari...  Subbaiah Gari Hotel
# 3  https://www.zomato.com/hyderabad/paradise-biry...     Paradise Biryani
# 4  https://www.zomato.com/hyderabad/pista-house-b...   Pista House Bakery
#
#   ratings                                            cuisine  price for one
# 0     3.7            Chinese, Bakery, Sichuan, Pizza, Burger            100
# 1     3.9    Burger, Fast Food, Biryani, Desserts, Beverages            100
# 2     4.1                       South Indian, Andhra, Mithai            100
# 3     3.9                Biryani, Kebab, Desserts, Beverages            100
# 4     4.3  Fast Food, Sandwich, Pizza, Burger, Wraps, Rol...            100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 657 entries, 0 to 656
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   links          657 non-null    object
#  1   names          657 non-null    object
#  2   ratings        657 non-null    object
#  3   cuisine        657 non-null    object
#  4   price for one  657 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 25.8+ KB

# %%
df.isnull().sum()
# Out:
# links            0
# names            0
# ratings          0
# cuisine          0
# price for one    0
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#                                                links                names  \
# 0  https://www.zomato.com/hyderabad/sahara-bakers...        Sahara Bakers
# 1   https://www.zomato.com/hyderabad/kfc-abids/order                  KFC
# 2  https://www.zomato.com/hyderabad/subbaiah-gari...  Subbaiah Gari Hotel
# 3  https://www.zomato.com/hyderabad/paradise-biry...     Paradise Biryani
# 4  https://www.zomato.com/hyderabad/pista-house-b...   Pista House Bakery
#
#   ratings                                            cuisine  price for one
# 0     3.7            Chinese, Bakery, Sichuan, Pizza, Burger            100
# 1     3.9    Burger, Fast Food, Biryani, Desserts, Beverages            100
# 2     4.1                       South Indian, Andhra, Mithai            100
# 3     3.9                Biryani, Kebab, Desserts, Beverages            100
# 4     4.3  Fast Food, Sandwich, Pizza, Burger, Wraps, Rol...            100

# %%
print("Average Customer Rating:", pd.to_numeric(df["ratings"], errors="coerce").mean())
# Out:
# Average Customer Rating: 3.946101694915254

# %%
highest = df.loc[pd.to_numeric(df["ratings"], errors="coerce").idxmax()]
print("Restaurant with Highest Rating:")
print("Name:", highest["names"])
print("Rating:", highest["ratings"])
# Out:
# Restaurant with Highest Rating:
# Name: Sri Krishna Sweets
# Rating: 4.7

# %%
print("Average Price for One Person:", df["price for one"].mean())
# Out:
# Average Price for One Person: 167.71186440677965

# %%
top10 = df.sort_values(by="ratings", ascending=False).head(10)

print("Top 10 Restaurants with the Highest Rating")
print(top10[["names", "ratings"]])
# Out:
# Top 10 Restaurants with the Highest Rating
#                          names  ratings
# 450         Sri Krishna Sweets      4.7
# 72                Almond House      4.6
# 184                   Euphoria      4.6
# 496               US Live Pops      4.6
# 611         Mimee's Chocolates      4.6
# 150  Abhiruchi Swaghruha Foods      4.5
# 559   Sri Shagun Mithai Vatika      4.5
# 22    NIC - Natural Ice Creams      4.5
# 214              Madhur Sweets      4.5
# 45             Arun Ice Creams      4.5

# %%
print("Top 10 Most Common Cuisines")
print(df["cuisine"].value_counts().head(10))
# Out:
# Top 10 Most Common Cuisines
# cuisine
# South Indian             54
# Bakery, Desserts         22
# Mithai, Street Food      21
# Mithai                   13
# North Indian, Chinese    11
# North Indian              9
# Bakery                    8
# Ice Cream, Desserts       8
# Mithai, Desserts          7
# Desserts, Ice Cream       6
# Name: count, dtype: int64

# %%
top10 = df.sort_values(by="ratings", ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top10["names"], top10["ratings"])
plt.title("Top 10 Highest Rated Restaurants")
plt.xlabel("Restaurant Name")
plt.ylabel("Rating")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["ratings"], bins=10)
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Ratings")
plt.ylabel("Number of Restaurants")
plt.show()

# %%
top_cuisine = df["cuisine"].value_counts().head(10)

plt.figure(figsize=(8,8))
plt.pie(top_cuisine.values,
        labels=top_cuisine.index,
        autopct="%1.1f%%",
        startangle=90)

plt.title("Top 10 Most Common Cuisines")
plt.show()

# %% [markdown]
# ## Descriptive Analysis Performed
#
# The following business questions were analyzed using the Hyderabad Restaurants dataset:
#
# 1. What is the average customer rating?
# 2. Which restaurant has the highest customer rating?
# 3. What is the average price for one person?
# 4. Which are the top 10 restaurants with the highest ratings?
# 5. What are the top 10 most common cuisines?
#
# ## Data Visualizations Created
#
# The following charts were created to support the analysis:
#
# 1. Bar Chart – Top 10 Highest Rated Restaurants
# 2. Histogram – Distribution of Restaurant Ratings
# 3. Pie Chart – Top 10 Most Common Cuisines
#
# ## Conclusion
#
# The descriptive analysis of the Hyderabad Restaurants dataset shows that the average customer rating is approximately 3.95, indicating that most restaurants provide good service and customer satisfaction. The analysis also identified the highest-rated restaurants, the average price for one person, and the most popular cuisines among customers. These insights can help restaurant owners understand customer preferences, improve their services, and make better business decisions.
